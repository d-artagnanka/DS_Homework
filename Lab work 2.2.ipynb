# %% [markdown]
# ___
#
# <a href='https://mainacademy.ua/'> <img src='https://mainacademy.ua/wp-content/uploads/2019/03/logo-main.png' alt = 'Хмм, щось з інтернетом'/></a>
# ___
#
# # Module 2: Basic Python

# %% [markdown]
# ## Lab work 2.2

# %% [markdown]
# #### Мета:
#
# * навчитися працювати із основними інструкціями Python;
# * ознайомитися із базовими алгоритмами;

# %% [markdown]
# ### Завдання 1

# %% [markdown]
# Для трьох введених натуральних чисел (користувач вводить числа через пробіл) знайдіть мінімальне та максимальне

# %%
numbers = input().split()
print(max(numbers))
print(min(numbers))
# Out:
# 4 5 9
# 9
# 4

# %% [markdown]
# ### Завдання 2

# %% [markdown]
# Програма приймає на вхід два параметри: стать спортсмена(`sex = (f, m)`) та вік спортсмена(`age = [0,100]`).  Спортсмен-дівчина може брати участь у змаганні, якщо її вік більший 18, спортсмен-хлопець - якщо вік більший 16
#
# Якщо введеніть не коректні дані, виведіть повідомлення про помилку

# %%
while True:
    try:   
        sex = input()
        age = float(input())
        if sex == 'f' and age <18:
            print('paticipant is not old enough')
        elif sex == 'm' and age <16:
            print('paticipant is not old enough')
        elif sex !='m' and sex !='f':
            print('wrong sex, try again')
        else:
            print('you can paticipate')
    except Exception as e:
            print('try again')
            print(f'your error is: {e}')
# Out:
# 2
# f
# 16
# paticipant is not old enough
# f
# 18
# you can paticipate
# m
# 14
# paticipant is not old enough

# %% [markdown]
# ### Завдання 3

# %% [markdown]
# Для введеного натурального числа побудуйте драбинку.
#
# Наприклад, якщо N = 5, драбинка буде мати вигляд:
#
# &
#
# &&
#
# &&&
#
# &&&&
#
# &&&&&

# %%
N = int(input())

i=0
while i <=N:
    print ('&'*i)
    i +=1
# Out:
# 5
#
# &
# &&
# &&&
# &&&&
# &&&&&

# %% [markdown]
# ### Завдання 4

# %% [markdown]
# Із заданого речення виведіть кожне слово і його довжину

# %%
sentence = 'My favourite tutor in academy is Ihor'
s=sentence.split(' ')

for i in s:
    print(i, len(i))
# Out:
# My 2
# favourite 9
# tutor 5
# in 2
# academy 7
# is 2
# Ihor 4

# %% [markdown]
# ### Завдання 5

# %% [markdown]
# Для заданого тексту реалізуйте:
# * Знайдіть кількість слів
# * Знайдіть кількість унікальних слів
# * Своірть словник, де ключе буде слово із тексту, значенням - частота зустрічання в тексті
# * Виведіть топ-3 слів, що найчастіше зустрічаються
#
# Вважаємо, що слово це стрічка з трьох і більше букв, очищена від знаків пунктуації

# %%
text = """До чого ж гарно і весело було в нашому горóді! Ото як вийти з сіней та подивись навколо — геть-чисто все зелене та буйне. А сад було як зацвіте весною! А що робилось на початку літа — огірки цвітуть, гарбузи цвітуть, картопля цвіте. Цвіте малина, смородина, тютюн, квасоля. А соняшника, а маку, буряків, лободи, укропу, моркви! Чого тільки не насадить наша невгамовна мати.

— Нічого в світі так я не люблю, як саджати що-небудь у землю, щоб проізростало. Коли вилізає з землі всяка рослиночка, ото мені радість,— любила проказувати вона.

Город до того переповнявсь рослинами, що десь серед літа вони вже не вміщалися в ньому. Вони лізли одна на одну, переплітались, душились, дерлися на хлів, на стріху, повзли на тин, а гарбузи звисали з тину прямо на вулицю.

А малини — красної, білої! А вишень, а груш солодких, було. як наїсися,— цілий день живіт як бубон.

І росло ще, пригадую, багато тютюну, в якому ми, маленькі, ходили, мов у лісі, в якому пізнали перші мозолі на дитячих руках.

А вздовж тину, за старою повіткою, росли великі кущі смородини, бузини і ще якихось невідомих рослин. Там неслися кури нишком од матері і різне дрібне птаство. Туди ми рідко лазили. Там було темно навіть удень, і ми боялись гадюки. Хто з нас у дитинстві не боявся гадюки, так за все життя й не побачивши її ніде?

Коло хати, що стояла в саду, цвіли квіти, а за хатою, проти сінешніх дверей, коло вишень,— поросла полином стара погребня з одкритою лядою, звідки завжди пахло цвіллю. Там, у льоху, в присмерку плигали жаби. Напевно, там водилися й гадюки.

На погребні любив спати дід.

У нас був дід дуже схожий на бога. Коли я молився богу, я завжди бачив на покуті портрет діда в старих срібнофольгових шатах, а сам дід лежав на печі і тихо кашляв, слухаючи своїх молитов.

У неділю перед богами горіла маленька синенька лампадка, в яку завжди набиралось повно мух. Образ святого Миколая також був схожий на діда, особливо коли дід часом підстригав собі бороду і випивав перед обідом чарку горілки з перцем, і мати не лаялась. Святий Федосій більш скидався на батька. Федосію я не молився, в нього була ще темна борода, а в руці гирлига, одягнена чомусь у білу хустку. А от бог, схожий на діда, той тримав в одній руці круглу сільничку, а трьома пýчками другої неначе збирався взяти зубок часнику
Звали нашого діда, як я вже потім довідавсь, Семеном. Він був високий і худий, і чоло в нього високе, хвилясте довге волосся сиве, а борода біла. І була в нього велика грижа ще з молодих чумацьких літ. Пахнув дід теплою землею і трохи млином. Він був письменний по-церковному і в неділю любив урочисто читати псалтир. Ні дід, ні ми не розуміли прочитаного, і це завжди хвилювало нас, як дивна таємниця, що надавала прочитаному особливого, небуденного смислу.

Мати ненавиділа діда і вважала його за чорнокнижника. Ми не вірили матері і захищали діда од її нападів, бо псалтир всередині був не чорний, а білий, а товста шкіряна палітурка — коричнева, як гречаний мед чи стара халява. Зрештою, мати крадькома таки знищила псалтир. Вона спалила його в печі по одному листочку, боячись палити зразу весь, щоб він часом не вибухнув і не розніс печі.

Любив дід гарну бесіду й добре слово. Часом по дорозі на луг, коли хто питав у нього дорогу на Борзну чи на Батурин, він довго стояв посеред шляху і, махаючи пужалном, гукав услід подорожньому:

— Прямо, та й прямо, та й прямо, та й нікуди ж не звертайте!.. Добра людина поїхала, дай їй бог здоров'я,— зітхав він лагідно, коли подорожній нарешті зникав у кущах.

— А хто вона, діду, людина ота? Звідки вона?

— А бог її знає, хіба я знаю... Ну, чого стоїш як укопаний? — звертався дід до коня, сідаючи на воза.— Но, трогай-бо, ну...

Він був наш добрий дух лугу і риби. Гриби й ягоди збирав він у лісі краще за нас усіх і розмовляв з кіньми, з телятами, з травами, з старою грушею і дубом — з усім живим, що росло і рухалось навколо.
Більш за все на світі любив дід сонце. Він прожив під сонцем коло ста літ, ніколи не ховаючись у холодок. Так під сонцем на погребні, коло яблуні, він і помер, коли прийшов його час.

Дід любив кашляти. Кашляв він часом так довго й гучно, що скільки ми не старалися, ніхто не міг його як слід передражнити. Його кашель чув увесь куток. Старі люди по дідовому кашлю вгадували навіть погоду.
"""

print(len(text))
t=set(text)
print(len(t))
# Out:
# 4260
# 65

# %% [markdown]
# import string
# import re
#
# s=text.lower()
# s = re.sub(r'[^\w\s]','',s)
# s=s.replace('\n', ' ')
#
# txt_l=s.split(' ')
# txt_l

# %%
import string
import re
s=text.lower()
match_pattern = re.findall(r'\b[a-я]{3,15}\b', s)
print(match_pattern)
# Out:
# ['чого', 'гарно', 'весело', 'було', 'нашому', 'ото', 'вийти', 'подивись', 'навколо', 'геть', 'чисто', 'все', 'зелене', 'буйне', 'сад', 'було', 'весною', 'робилось', 'початку', 'гарбузи', 'картопля', 'малина', 'смородина', 'тютюн', 'квасоля', 'соняшника', 'маку', 'лободи', 'укропу', 'моркви', 'чого', 'насадить', 'наша', 'невгамовна', 'мати', 'так', 'люблю', 'саджати', 'небудь', 'землю', 'щоб', 'коли', 'всяка', 'рослиночка', 'ото', 'любила', 'проказувати', 'вона', 'город', 'того', 'переповнявсь', 'рослинами', 'десь', 'серед', 'вони', 'вже', 'ньому', 'вони', 'одна', 'одну', 'душились', 'дерлися', 'повзли', 'тин', 'гарбузи', 'звисали', 'тину', 'прямо', 'вулицю', 'малини', 'вишень', 'груш', 'солодких', 'було', 'день', 'бубон', 'росло', 'пригадую', 'багато', 'тютюну', 'якому', 'ходили', 'мов', 'якому', 'дитячих', 'руках', 'вздовж', 'тину', 'старою', 'росли', 'смородини', 'бузини', 'якихось', 'рослин', 'там', 'неслися', 'кури', 'нишком', 'птаство', 'туди', 'лазили', 'там', 'було', 'темно', 'удень', 'боялись', 'гадюки', 'хто', 'нас', 'боявся', 'гадюки', 'так', 'все', 'життя', 'побачивши', 'коло', 'хати', 'стояла', 'саду', 'хатою', 'проти', 'дверей', 'коло', 'вишень', 'поросла', 'полином', 'стара', 'погребня', 'одкритою', 'лядою', 'завжди', 'пахло', 'там', 'льоху', 'присмерку', 'плигали', 'жаби', 'напевно', 'там', 'водилися', 'гадюки', 'любив', 'спати', 'нас', 'був', 'дуже', 'схожий', 'бога', 'коли', 'молився', 'богу', 'завжди', 'бачив', 'портрет', 'старих', 'шатах', 'сам', 'лежав', 'тихо', 'кашляв', 'слухаючи', 'молитов', 'перед', 'богами', 'маленька', 'синенька', 'лампадка', 'яку', 'завжди', 'набиралось', 'повно', 'мух', 'образ', 'святого', 'миколая', 'також', 'був', 'схожий', 'особливо', 'коли', 'часом', 'бороду', 'випивав', 'перед', 'чарку', 'перцем', 'мати', 'лаялась', 'святий', 'скидався', 'батька', 'молився', 'нього', 'була', 'темна', 'борода', 'гирлига', 'одягнена', 'чомусь', 'хустку', 'бог', 'схожий', 'той', 'тримав', 'круглу', 'трьома', 'пýчками', 'неначе', 'збирався', 'взяти', 'зубок', 'часнику', 'звали', 'нашого', 'вже', 'семеном', 'був', 'високий', 'худий', 'чоло', 'нього', 'високе', 'хвилясте', 'довге', 'волосся', 'сиве', 'борода', 'була', 'нього', 'велика', 'грижа', 'молодих', 'чумацьких', 'пахнув', 'теплою', 'землею', 'трохи', 'млином', 'був', 'письменний', 'церковному', 'любив', 'урочисто', 'читати', 'псалтир', 'прочитаного', 'завжди', 'хвилювало', 'нас', 'дивна', 'надавала', 'прочитаному', 'особливого', 'небуденного', 'смислу', 'мати', 'вважала', 'його', 'чорнокнижника', 'захищали', 'псалтир', 'був', 'чорний', 'товста', 'коричнева', 'гречаний', 'мед', 'стара', 'халява', 'зрештою', 'мати', 'крадькома', 'таки', 'знищила', 'псалтир', 'вона', 'спалила', 'його', 'одному', 'листочку', 'боячись', 'палити', 'зразу', 'весь', 'щоб', 'часом', 'вибухнув', 'любив', 'гарну', 'добре', 'слово', 'часом', 'луг', 'коли', 'хто', 'питав', 'нього', 'дорогу', 'борзну', 'батурин', 'довго', 'стояв', 'посеред', 'шляху', 'махаючи', 'пужалном', 'гукав', 'подорожньому', 'прямо', 'прямо', 'прямо', 'звертайте', 'добра', 'людина', 'дай', 'бог', 'здоров', 'коли', 'зникав', 'кущах', 'хто', 'вона', 'людина', 'ота', 'вона', 'бог', 'знаю', 'чого', 'укопаний', 'звертався', 'коня', 'воза', 'трогай', 'був', 'наш', 'добрий', 'дух', 'лугу', 'риби', 'гриби', 'ягоди', 'збирав', 'краще', 'нас', 'розмовляв', 'телятами', 'травами', 'старою', 'грушею', 'дубом', 'живим', 'росло', 'рухалось', 'навколо', 'все', 'любив', 'сонце', 'прожив', 'сонцем', 'коло', 'ста', 'ховаючись', 'холодок', 'так', 'сонцем', 'коло', 'помер', 'коли', 'прийшов', 'його', 'час', 'любив', 'кашляти', 'кашляв', 'часом', 'так', 'довго', 'гучно', 'старалися', 'його', 'передражнити', 'його', 'кашель', 'чув', 'увесь', 'куток', 'люди', 'кашлю', 'вгадували', 'погоду']

# %%
frequency = {}

# %%
 for word in match_pattern:
    count = frequency.get(word,0)
    frequency[word] = count + 1
     
frequency_list = frequency.keys()
 
for words in frequency_list:
    print (words, frequency[words])
# Out:
# чого 3
# гарно 1
# весело 1
# було 4
# нашому 1
# ото 2
# вийти 1
# подивись 1
# навколо 2
# геть 1
# чисто 1
# все 3
# зелене 1
# буйне 1
# сад 1
# весною 1
# робилось 1
# початку 1
# гарбузи 2
# картопля 1
# малина 1
# смородина 1
# тютюн 1
# квасоля 1
# соняшника 1
# маку 1
# лободи 1
# укропу 1
# моркви 1
# насадить 1
# наша 1
# невгамовна 1
# мати 4
# так 4
# люблю 1
# саджати 1
# небудь 1
# землю 1
# щоб 2
# коли 6
# всяка 1
# рослиночка 1
# любила 1
# проказувати 1
# вона 4
# город 1
# того 1
# переповнявсь 1
# рослинами 1
# десь 1
# серед 1
# вони 2
# вже 2
# ньому 1
# одна 1
# одну 1
# душились 1
# дерлися 1
# повзли 1
# тин 1
# звисали 1
# тину 2
# прямо 4
# вулицю 1
# малини 1
# вишень 2
# груш 1
# солодких 1
# день 1
# бубон 1
# росло 2
# пригадую 1
# багато 1
# тютюну 1
# якому 2
# ходили 1
# мов 1
# дитячих 1
# руках 1
# вздовж 1
# старою 2
# росли 1
# смородини 1
# бузини 1
# якихось 1
# рослин 1
# там 4
# неслися 1
# кури 1
# нишком 1
# птаство 1
# туди 1
# лазили 1
# темно 1
# удень 1
# боялись 1
# гадюки 3
# хто 3
# нас 4
# боявся 1
# життя 1
# побачивши 1
# коло 4
# хати 1
# стояла 1
# саду 1
# хатою 1
# проти 1
# дверей 1
# поросла 1
# полином 1
# стара 2
# погребня 1
# одкритою 1
# лядою 1
# завжди 4
# пахло 1
# льоху 1
# присмерку 1
# плигали 1
# жаби 1
# напевно 1
# водилися 1
# любив 5
# спати 1
# був 6
# дуже 1
# схожий 3
# бога 1
# молився 2
# богу 1
# бачив 1
# портрет 1
# старих 1
# шатах 1
# сам 1
# лежав 1
# тихо 1
# кашляв 2
# слухаючи 1
# молитов 1
# перед 2
# богами 1
# маленька 1
# синенька 1
# лампадка 1
# яку 1
# набиралось 1
# повно 1
# мух 1
# образ 1
# святого 1
# миколая 1
# також 1
# особливо 1
# часом 4
# бороду 1
# випивав 1
# чарку 1
# перцем 1
# лаялась 1
# святий 1
# скидався 1
# батька 1
# нього 4
# була 2
# темна 1
# борода 2
# гирлига 1
# одягнена 1
# чомусь 1
# хустку 1
# бог 3
# той 1
# тримав 1
# круглу 1
# трьома 1
# пýчками 1
# неначе 1
# збирався 1
# взяти 1
# зубок 1
# часнику 1
# звали 1
# нашого 1
# семеном 1
# високий 1
# худий 1
# чоло 1
# високе 1
# хвилясте 1
# довге 1
# волосся 1
# сиве 1
# велика 1
# грижа 1
# молодих 1
# чумацьких 1
# пахнув 1
# теплою 1
# землею 1
# трохи 1
# млином 1
# письменний 1
# церковному 1
# урочисто 1
# читати 1
# псалтир 3
# прочитаного 1
# хвилювало 1
# дивна 1
# надавала 1
# прочитаному 1
# особливого 1
# небуденного 1
# смислу 1
# вважала 1
# його 5
# чорнокнижника 1
# захищали 1
# чорний 1
# товста 1
# коричнева 1
# гречаний 1
# мед 1
# халява 1
# зрештою 1
# крадькома 1
# таки 1
# знищила 1
# спалила 1
# одному 1
# листочку 1
# боячись 1
# палити 1
# зразу 1
# весь 1
# вибухнув 1
# гарну 1
# добре 1
# слово 1
# луг 1
# питав 1
# дорогу 1
# борзну 1
# батурин 1
# довго 2
# стояв 1
# посеред 1
# шляху 1
# махаючи 1
# пужалном 1
# гукав 1
# подорожньому 1
# звертайте 1
# добра 1
# людина 2
# дай 1
# здоров 1
# зникав 1
# кущах 1
# ота 1
# знаю 1
# укопаний 1
# звертався 1
# коня 1
# воза 1
# трогай 1
# наш 1
# добрий 1
# дух 1
# лугу 1
# риби 1
# гриби 1
# ягоди 1
# збирав 1
# краще 1
# розмовляв 1
# телятами 1
# травами 1
# грушею 1
# дубом 1
# живим 1
# рухалось 1
# сонце 1
# прожив 1
# сонцем 2
# ста 1
# ховаючись 1
# холодок 1
# помер 1
# прийшов 1
# час 1
# кашляти 1
# гучно 1
# старалися 1
# передражнити 1
# кашель 1
# чув 1
# увесь 1
# куток 1
# люди 1
# кашлю 1
# вгадували 1
# погоду 1

# %%
frequency
# Out:
# {'чого': 3,
#  'гарно': 1,
#  'весело': 1,
#  'було': 4,
#  'нашому': 1,
#  'ото': 2,
#  'вийти': 1,
#  'подивись': 1,
#  'навколо': 2,
#  'геть': 1,
#  'чисто': 1,
#  'все': 3,
#  'зелене': 1,
#  'буйне': 1,
#  'сад': 1,
#  'весною': 1,
#  'робилось': 1,
#  'початку': 1,
#  'гарбузи': 2,
#  'картопля': 1,
#  'малина': 1,
#  'смородина': 1,
#  'тютюн': 1,
#  'квасоля': 1,
#  'соняшника': 1,
#  'маку': 1,
#  'лободи': 1,
#  'укропу': 1,
#  'моркви': 1,
#  'насадить': 1,
#  'наша': 1,
#  'невгамовна': 1,
#  'мати': 4,
#  'так': 4,
#  'люблю': 1,
#  'саджати': 1,
#  'небудь': 1,
#  'землю': 1,
#  'щоб': 2,
#  'коли': 6,
#  'всяка': 1,
#  'рослиночка': 1,
#  'любила': 1,
#  'проказувати': 1,
#  'вона': 4,
#  'город': 1,
#  'того': 1,
#  'переповнявсь': 1,
#  'рослинами': 1,
#  'десь': 1,
#  'серед': 1,
#  'вони': 2,
#  'вже': 2,
#  'ньому': 1,
#  'одна': 1,
#  'одну': 1,
#  'душились': 1,
#  'дерлися': 1,
#  'повзли': 1,
#  'тин': 1,
#  'звисали': 1,
#  'тину': 2,
#  'прямо': 4,
#  'вулицю': 1,
#  'малини': 1,
#  'вишень': 2,
#  'груш': 1,
#  'солодких': 1,
#  'день': 1,
#  'бубон': 1,
#  'росло': 2,
#  'пригадую': 1,
#  'багато': 1,
#  'тютюну': 1,
#  'якому': 2,
#  'ходили': 1,
#  'мов': 1,
#  'дитячих': 1,
#  'руках': 1,
#  'вздовж': 1,
#  'старою': 2,
#  'росли': 1,
#  'смородини': 1,
#  'бузини': 1,
#  'якихось': 1,
#  'рослин': 1,
#  'там': 4,
#  'неслися': 1,
#  'кури': 1,
#  'нишком': 1,
#  'птаство': 1,
#  'туди': 1,
#  'лазили': 1,
#  'темно': 1,
#  'удень': 1,
#  'боялись': 1,
#  'гадюки': 3,
#  'хто': 3,
#  'нас': 4,
#  'боявся': 1,
#  'життя': 1,
#  'побачивши': 1,
#  'коло': 4,
#  'хати': 1,
#  'стояла': 1,
#  'саду': 1,
#  'хатою': 1,
#  'проти': 1,
#  'дверей': 1,
#  'поросла': 1,
#  'полином': 1,
#  'стара': 2,
#  'погребня': 1,
#  'одкритою': 1,
#  'лядою': 1,
#  'завжди': 4,
#  'пахло': 1,
#  'льоху': 1,
#  'присмерку': 1,
#  'плигали': 1,
#  'жаби': 1,
#  'напевно': 1,
#  'водилися': 1,
#  'любив': 5,
#  'спати': 1,
#  'був': 6,
#  'дуже': 1,
#  'схожий': 3,
#  'бога': 1,
#  'молився': 2,
#  'богу': 1,
#  'бачив': 1,
#  'портрет': 1,
#  'старих': 1,
#  'шатах': 1,
#  'сам': 1,
#  'лежав': 1,
#  'тихо': 1,
#  'кашляв': 2,
#  'слухаючи': 1,
#  'молитов': 1,
#  'перед': 2,
#  'богами': 1,
#  'маленька': 1,
#  'синенька': 1,
#  'лампадка': 1,
#  'яку': 1,
#  'набиралось': 1,
#  'повно': 1,
#  'мух': 1,
#  'образ': 1,
#  'святого': 1,
#  'миколая': 1,
#  'також': 1,
#  'особливо': 1,
#  'часом': 4,
#  'бороду': 1,
#  'випивав': 1,
#  'чарку': 1,
#  'перцем': 1,
#  'лаялась': 1,
#  'святий': 1,
#  'скидався': 1,
#  'батька': 1,
#  'нього': 4,
#  'була': 2,
#  'темна': 1,
#  'борода': 2,
#  'гирлига': 1,
#  'одягнена': 1,
#  'чомусь': 1,
#  'хустку': 1,
#  'бог': 3,
#  'той': 1,
#  'тримав': 1,
#  'круглу': 1,
#  'трьома': 1,
#  'пýчками': 1,
#  'неначе': 1,
#  'збирався': 1,
#  'взяти': 1,
#  'зубок': 1,
#  'часнику': 1,
#  'звали': 1,
#  'нашого': 1,
#  'семеном': 1,
#  'високий': 1,
#  'худий': 1,
#  'чоло': 1,
#  'високе': 1,
#  'хвилясте': 1,
#  'довге': 1,
#  'волосся': 1,
#  'сиве': 1,
#  'велика': 1,
#  'грижа': 1,
#  'молодих': 1,
#  'чумацьких': 1,
#  'пахнув': 1,
#  'теплою': 1,
#  'землею': 1,
#  'трохи': 1,
#  'млином': 1,
#  'письменний': 1,
#  'церковному': 1,
#  'урочисто': 1,
#  'читати': 1,
#  'псалтир': 3,
#  'прочитаного': 1,
#  'хвилювало': 1,
#  'дивна': 1,
#  'надавала': 1,
#  'прочитаному': 1,
#  'особливого': 1,
#  'небуденного': 1,
#  'смислу': 1,
#  'вважала': 1,
#  'його': 5,
#  'чорнокнижника': 1,
#  'захищали': 1,
#  'чорний': 1,
#  'товста': 1,
#  'коричнева': 1,
#  'гречаний': 1,
#  'мед': 1,
#  'халява': 1,
#  'зрештою': 1,
#  'крадькома': 1,
#  'таки': 1,
#  'знищила': 1,
#  'спалила': 1,
#  'одному': 1,
#  'листочку': 1,
#  'боячись': 1,
#  'палити': 1,
#  'зразу': 1,
#  'весь': 1,
#  'вибухнув': 1,
#  'гарну': 1,
#  'добре': 1,
#  'слово': 1,
#  'луг': 1,
#  'питав': 1,
#  'дорогу': 1,
#  'борзну': 1,
#  'батурин': 1,
#  'довго': 2,
#  'стояв': 1,
#  'посеред': 1,
#  'шляху': 1,
#  'махаючи': 1,
#  'пужалном': 1,
#  'гукав': 1,
#  'подорожньому': 1,
#  'звертайте': 1,
#  'добра': 1,
#  'людина': 2,
#  'дай': 1,
#  'здоров': 1,
#  'зникав': 1,
#  'кущах': 1,
#  'ота': 1,
#  'знаю': 1,
#  'укопаний': 1,
#  'звертався': 1,
#  'коня': 1,
#  'воза': 1,
#  'трогай': 1,
#  'наш': 1,
#  'добрий': 1,
#  'дух': 1,
#  'лугу': 1,
#  'риби': 1,
#  'гриби': 1,
#  'ягоди': 1,
#  'збирав': 1,
#  'краще': 1,
#  'розмовляв': 1,
#  'телятами': 1,
#  'травами': 1,
#  'грушею': 1,
#  'дубом': 1,
#  'живим': 1,
#  'рухалось': 1,
#  'сонце': 1,
#  'прожив': 1,
#  'сонцем': 2,
#  'ста': 1,
#  'ховаючись': 1,
#  'холодок': 1,
#  'помер': 1,
#  'прийшов': 1,
#  'час': 1,
#  'кашляти': 1,
#  'гучно': 1,
#  'старалися': 1,
#  'передражнити': 1,
#  'кашель': 1,
#  'чув': 1,
#  'увесь': 1,
#  'куток': 1,
#  'люди': 1,
#  'кашлю': 1,
#  'вгадували': 1,
#  'погоду': 1}

# %%
a = dict(sorted(frequency.items(), reverse = True, key=lambda x: x[1]))
a
# Out:
# {'коли': 6,
#  'був': 6,
#  'любив': 5,
#  'його': 5,
#  'було': 4,
#  'мати': 4,
#  'так': 4,
#  'вона': 4,
#  'прямо': 4,
#  'там': 4,
#  'нас': 4,
#  'коло': 4,
#  'завжди': 4,
#  'часом': 4,
#  'нього': 4,
#  'чого': 3,
#  'все': 3,
#  'гадюки': 3,
#  'хто': 3,
#  'схожий': 3,
#  'бог': 3,
#  'псалтир': 3,
#  'ото': 2,
#  'навколо': 2,
#  'гарбузи': 2,
#  'щоб': 2,
#  'вони': 2,
#  'вже': 2,
#  'тину': 2,
#  'вишень': 2,
#  'росло': 2,
#  'якому': 2,
#  'старою': 2,
#  'стара': 2,
#  'молився': 2,
#  'кашляв': 2,
#  'перед': 2,
#  'була': 2,
#  'борода': 2,
#  'довго': 2,
#  'людина': 2,
#  'сонцем': 2,
#  'гарно': 1,
#  'весело': 1,
#  'нашому': 1,
#  'вийти': 1,
#  'подивись': 1,
#  'геть': 1,
#  'чисто': 1,
#  'зелене': 1,
#  'буйне': 1,
#  'сад': 1,
#  'весною': 1,
#  'робилось': 1,
#  'початку': 1,
#  'картопля': 1,
#  'малина': 1,
#  'смородина': 1,
#  'тютюн': 1,
#  'квасоля': 1,
#  'соняшника': 1,
#  'маку': 1,
#  'лободи': 1,
#  'укропу': 1,
#  'моркви': 1,
#  'насадить': 1,
#  'наша': 1,
#  'невгамовна': 1,
#  'люблю': 1,
#  'саджати': 1,
#  'небудь': 1,
#  'землю': 1,
#  'всяка': 1,
#  'рослиночка': 1,
#  'любила': 1,
#  'проказувати': 1,
#  'город': 1,
#  'того': 1,
#  'переповнявсь': 1,
#  'рослинами': 1,
#  'десь': 1,
#  'серед': 1,
#  'ньому': 1,
#  'одна': 1,
#  'одну': 1,
#  'душились': 1,
#  'дерлися': 1,
#  'повзли': 1,
#  'тин': 1,
#  'звисали': 1,
#  'вулицю': 1,
#  'малини': 1,
#  'груш': 1,
#  'солодких': 1,
#  'день': 1,
#  'бубон': 1,
#  'пригадую': 1,
#  'багато': 1,
#  'тютюну': 1,
#  'ходили': 1,
#  'мов': 1,
#  'дитячих': 1,
#  'руках': 1,
#  'вздовж': 1,
#  'росли': 1,
#  'смородини': 1,
#  'бузини': 1,
#  'якихось': 1,
#  'рослин': 1,
#  'неслися': 1,
#  'кури': 1,
#  'нишком': 1,
#  'птаство': 1,
#  'туди': 1,
#  'лазили': 1,
#  'темно': 1,
#  'удень': 1,
#  'боялись': 1,
#  'боявся': 1,
#  'життя': 1,
#  'побачивши': 1,
#  'хати': 1,
#  'стояла': 1,
#  'саду': 1,
#  'хатою': 1,
#  'проти': 1,
#  'дверей': 1,
#  'поросла': 1,
#  'полином': 1,
#  'погребня': 1,
#  'одкритою': 1,
#  'лядою': 1,
#  'пахло': 1,
#  'льоху': 1,
#  'присмерку': 1,
#  'плигали': 1,
#  'жаби': 1,
#  'напевно': 1,
#  'водилися': 1,
#  'спати': 1,
#  'дуже': 1,
#  'бога': 1,
#  'богу': 1,
#  'бачив': 1,
#  'портрет': 1,
#  'старих': 1,
#  'шатах': 1,
#  'сам': 1,
#  'лежав': 1,
#  'тихо': 1,
#  'слухаючи': 1,
#  'молитов': 1,
#  'богами': 1,
#  'маленька': 1,
#  'синенька': 1,
#  'лампадка': 1,
#  'яку': 1,
#  'набиралось': 1,
#  'повно': 1,
#  'мух': 1,
#  'образ': 1,
#  'святого': 1,
#  'миколая': 1,
#  'також': 1,
#  'особливо': 1,
#  'бороду': 1,
#  'випивав': 1,
#  'чарку': 1,
#  'перцем': 1,
#  'лаялась': 1,
#  'святий': 1,
#  'скидався': 1,
#  'батька': 1,
#  'темна': 1,
#  'гирлига': 1,
#  'одягнена': 1,
#  'чомусь': 1,
#  'хустку': 1,
#  'той': 1,
#  'тримав': 1,
#  'круглу': 1,
#  'трьома': 1,
#  'пýчками': 1,
#  'неначе': 1,
#  'збирався': 1,
#  'взяти': 1,
#  'зубок': 1,
#  'часнику': 1,
#  'звали': 1,
#  'нашого': 1,
#  'семеном': 1,
#  'високий': 1,
#  'худий': 1,
#  'чоло': 1,
#  'високе': 1,
#  'хвилясте': 1,
#  'довге': 1,
#  'волосся': 1,
#  'сиве': 1,
#  'велика': 1,
#  'грижа': 1,
#  'молодих': 1,
#  'чумацьких': 1,
#  'пахнув': 1,
#  'теплою': 1,
#  'землею': 1,
#  'трохи': 1,
#  'млином': 1,
#  'письменний': 1,
#  'церковному': 1,
#  'урочисто': 1,
#  'читати': 1,
#  'прочитаного': 1,
#  'хвилювало': 1,
#  'дивна': 1,
#  'надавала': 1,
#  'прочитаному': 1,
#  'особливого': 1,
#  'небуденного': 1,
#  'смислу': 1,
#  'вважала': 1,
#  'чорнокнижника': 1,
#  'захищали': 1,
#  'чорний': 1,
#  'товста': 1,
#  'коричнева': 1,
#  'гречаний': 1,
#  'мед': 1,
#  'халява': 1,
#  'зрештою': 1,
#  'крадькома': 1,
#  'таки': 1,
#  'знищила': 1,
#  'спалила': 1,
#  'одному': 1,
#  'листочку': 1,
#  'боячись': 1,
#  'палити': 1,
#  'зразу': 1,
#  'весь': 1,
#  'вибухнув': 1,
#  'гарну': 1,
#  'добре': 1,
#  'слово': 1,
#  'луг': 1,
#  'питав': 1,
#  'дорогу': 1,
#  'борзну': 1,
#  'батурин': 1,
#  'стояв': 1,
#  'посеред': 1,
#  'шляху': 1,
#  'махаючи': 1,
#  'пужалном': 1,
#  'гукав': 1,
#  'подорожньому': 1,
#  'звертайте': 1,
#  'добра': 1,
#  'дай': 1,
#  'здоров': 1,
#  'зникав': 1,
#  'кущах': 1,
#  'ота': 1,
#  'знаю': 1,
#  'укопаний': 1,
#  'звертався': 1,
#  'коня': 1,
#  'воза': 1,
#  'трогай': 1,
#  'наш': 1,
#  'добрий': 1,
#  'дух': 1,
#  'лугу': 1,
#  'риби': 1,
#  'гриби': 1,
#  'ягоди': 1,
#  'збирав': 1,
#  'краще': 1,
#  'розмовляв': 1,
#  'телятами': 1,
#  'травами': 1,
#  'грушею': 1,
#  'дубом': 1,
#  'живим': 1,
#  'рухалось': 1,
#  'сонце': 1,
#  'прожив': 1,
#  'ста': 1,
#  'ховаючись': 1,
#  'холодок': 1,
#  'помер': 1,
#  'прийшов': 1,
#  'час': 1,
#  'кашляти': 1,
#  'гучно': 1,
#  'старалися': 1,
#  'передражнити': 1,
#  'кашель': 1,
#  'чув': 1,
#  'увесь': 1,
#  'куток': 1,
#  'люди': 1,
#  'кашлю': 1,
#  'вгадували': 1,
#  'погоду': 1}

# %%
count=0
for k,v in a.items(): 
    print(k,v)
    count+=1
    if count>=3:
        break
# Out:
# коли 6
# був 6
# любив 5

# %% [markdown]
# ### Завдання 6

# %% [markdown]
# Напишіть функції, що:
# * рохраховує мінімальне та максимальне значення
# * середнє значення послідовності
# * медіану послідовності
# * частоту кожної цифри в послідовності
# * середнє квадратичне відхилення
#
# Послідовність чисел ганеруємо рандомно

# %%
import random

#генеруэмо тисячу чисел в діапазоні від 0 до 10
list_with_random_numbers = [random.randint(0,100) for i in range(1000)]

list_with_random_numbers
# Out:
# [91,
#  82,
#  20,
#  4,
#  57,
#  32,
#  48,
#  1,
#  96,
#  44,
#  48,
#  11,
#  73,
#  100,
#  20,
#  44,
#  62,
#  6,
#  0,
#  60,
#  28,
#  0,
#  94,
#  75,
#  17,
#  78,
#  57,
#  92,
#  5,
#  53,
#  75,
#  23,
#  53,
#  63,
#  0,
#  35,
#  4,
#  8,
#  37,
#  33,
#  90,
#  51,
#  46,
#  32,
#  86,
#  67,
#  1,
#  27,
#  76,
#  88,
#  100,
#  23,
#  36,
#  74,
#  81,
#  100,
#  76,
#  6,
#  18,
#  78,
#  12,
#  16,
#  8,
#  58,
#  43,
#  11,
#  52,
#  65,
#  33,
#  28,
#  19,
#  26,
#  25,
#  33,
#  43,
#  17,
#  66,
#  21,
#  90,
#  99,
#  94,
#  76,
#  21,
#  45,
#  23,
#  57,
#  83,
#  31,
#  43,
#  71,
#  75,
#  68,
#  40,
#  33,
#  98,
#  24,
#  60,
#  14,
#  29,
#  51,
#  51,
#  37,
#  48,
#  47,
#  96,
#  91,
#  15,
#  90,
#  79,
#  89,
#  10,
#  18,
#  40,
#  47,
#  88,
#  68,
#  48,
#  99,
#  83,
#  18,
#  91,
#  82,
#  83,
#  26,
#  33,
#  71,
#  31,
#  80,
#  23,
#  66,
#  52,
#  36,
#  59,
#  26,
#  91,
#  3,
#  43,
#  61,
#  41,
#  57,
#  41,
#  25,
#  78,
#  29,
#  44,
#  23,
#  25,
#  28,
#  56,
#  1,
#  88,
#  83,
#  53,
#  77,
#  74,
#  68,
#  33,
#  20,
#  35,
#  92,
#  68,
#  35,
#  19,
#  45,
#  65,
#  42,
#  6,
#  54,
#  83,
#  82,
#  41,
#  49,
#  21,
#  5,
#  10,
#  53,
#  57,
#  98,
#  5,
#  70,
#  44,
#  32,
#  32,
#  56,
#  57,
#  88,
#  77,
#  82,
#  37,
#  11,
#  88,
#  91,
#  50,
#  27,
#  63,
#  68,
#  2,
#  10,
#  70,
#  50,
#  72,
#  11,
#  50,
#  65,
#  75,
#  52,
#  89,
#  10,
#  62,
#  88,
#  88,
#  10,
#  32,
#  61,
#  26,
#  78,
#  24,
#  95,
#  49,
#  24,
#  88,
#  34,
#  20,
#  77,
#  87,
#  71,
#  24,
#  51,
#  94,
#  34,
#  3,
#  7,
#  66,
#  71,
#  48,
#  39,
#  64,
#  12,
#  70,
#  60,
#  80,
#  66,
#  75,
#  25,
#  86,
#  51,
#  49,
#  58,
#  55,
#  25,
#  89,
#  100,
#  34,
#  15,
#  28,
#  31,
#  66,
#  48,
#  47,
#  30,
#  50,
#  73,
#  51,
#  82,
#  98,
#  31,
#  79,
#  42,
#  61,
#  93,
#  62,
#  83,
#  78,
#  96,
#  21,
#  69,
#  99,
#  17,
#  74,
#  2,
#  44,
#  17,
#  11,
#  95,
#  83,
#  95,
#  43,
#  66,
#  28,
#  85,
#  42,
#  37,
#  22,
#  18,
#  45,
#  79,
#  29,
#  4,
#  67,
#  88,
#  61,
#  4,
#  32,
#  99,
#  38,
#  82,
#  76,
#  78,
#  39,
#  94,
#  63,
#  56,
#  91,
#  1,
#  80,
#  3,
#  57,
#  0,
#  43,
#  76,
#  64,
#  79,
#  100,
#  43,
#  19,
#  26,
#  5,
#  97,
#  99,
#  88,
#  82,
#  95,
#  33,
#  52,
#  11,
#  3,
#  67,
#  59,
#  81,
#  54,
#  75,
#  100,
#  85,
#  77,
#  33,
#  91,
#  49,
#  52,
#  52,
#  29,
#  28,
#  45,
#  12,
#  50,
#  58,
#  35,
#  28,
#  97,
#  85,
#  73,
#  84,
#  29,
#  88,
#  14,
#  77,
#  99,
#  42,
#  1,
#  49,
#  31,
#  97,
#  28,
#  95,
#  64,
#  6,
#  94,
#  42,
#  65,
#  95,
#  100,
#  98,
#  82,
#  73,
#  59,
#  94,
#  77,
#  31,
#  4,
#  88,
#  80,
#  100,
#  51,
#  69,
#  16,
#  86,
#  58,
#  35,
#  1,
#  49,
#  100,
#  15,
#  48,
#  10,
#  47,
#  83,
#  29,
#  26,
#  7,
#  49,
#  94,
#  59,
#  27,
#  4,
#  57,
#  98,
#  23,
#  17,
#  60,
#  49,
#  2,
#  66,
#  7,
#  94,
#  70,
#  73,
#  65,
#  17,
#  58,
#  89,
#  11,
#  58,
#  60,
#  25,
#  42,
#  73,
#  73,
#  25,
#  26,
#  12,
#  24,
#  70,
#  73,
#  19,
#  24,
#  93,
#  2,
#  53,
#  63,
#  78,
#  53,
#  83,
#  63,
#  60,
#  42,
#  55,
#  94,
#  63,
#  31,
#  73,
#  84,
#  0,
#  86,
#  67,
#  71,
#  14,
#  1,
#  27,
#  97,
#  33,
#  90,
#  36,
#  32,
#  81,
#  50,
#  55,
#  85,
#  58,
#  70,
#  100,
#  77,
#  63,
#  73,
#  32,
#  22,
#  74,
#  15,
#  3,
#  94,
#  89,
#  10,
#  94,
#  2,
#  43,
#  74,
#  35,
#  43,
#  4,
#  98,
#  26,
#  55,
#  90,
#  28,
#  99,
#  98,
#  88,
#  7,
#  56,
#  9,
#  79,
#  40,
#  93,
#  2,
#  65,
#  73,
#  92,
#  79,
#  43,
#  80,
#  74,
#  99,
#  10,
#  79,
#  33,
#  71,
#  89,
#  53,
#  90,
#  16,
#  36,
#  77,
#  17,
#  55,
#  51,
#  4,
#  6,
#  3,
#  81,
#  45,
#  3,
#  96,
#  33,
#  89,
#  0,
#  66,
#  71,
#  48,
#  45,
#  83,
#  11,
#  12,
#  1,
#  84,
#  4,
#  6,
#  64,
#  50,
#  37,
#  42,
#  97,
#  78,
#  88,
#  46,
#  82,
#  43,
#  40,
#  48,
#  78,
#  2,
#  18,
#  57,
#  97,
#  55,
#  52,
#  9,
#  26,
#  64,
#  98,
#  18,
#  2,
#  24,
#  32,
#  75,
#  80,
#  23,
#  18,
#  72,
#  99,
#  10,
#  41,
#  2,
#  30,
#  91,
#  29,
#  94,
#  27,
#  29,
#  8,
#  92,
#  46,
#  51,
#  17,
#  95,
#  24,
#  72,
#  93,
#  18,
#  5,
#  14,
#  8,
#  78,
#  40,
#  56,
#  16,
#  71,
#  31,
#  30,
#  53,
#  2,
#  28,
#  49,
#  41,
#  61,
#  4,
#  94,
#  38,
#  15,
#  78,
#  65,
#  38,
#  35,
#  78,
#  35,
#  57,
#  54,
#  96,
#  77,
#  71,
#  43,
#  42,
#  95,
#  45,
#  26,
#  35,
#  88,
#  72,
#  85,
#  34,
#  69,
#  95,
#  40,
#  32,
#  87,
#  70,
#  35,
#  22,
#  44,
#  20,
#  75,
#  48,
#  57,
#  33,
#  93,
#  79,
#  11,
#  96,
#  2,
#  87,
#  31,
#  5,
#  19,
#  94,
#  7,
#  35,
#  6,
#  78,
#  26,
#  66,
#  77,
#  71,
#  47,
#  55,
#  56,
#  95,
#  92,
#  12,
#  38,
#  59,
#  4,
#  76,
#  93,
#  42,
#  38,
#  47,
#  1,
#  82,
#  22,
#  53,
#  35,
#  78,
#  30,
#  45,
#  12,
#  31,
#  59,
#  6,
#  73,
#  28,
#  74,
#  28,
#  62,
#  37,
#  25,
#  18,
#  7,
#  67,
#  12,
#  38,
#  76,
#  76,
#  5,
#  15,
#  69,
#  80,
#  12,
#  82,
#  63,
#  58,
#  47,
#  69,
#  67,
#  16,
#  35,
#  22,
#  65,
#  36,
#  62,
#  84,
#  53,
#  39,
#  54,
#  78,
#  25,
#  77,
#  34,
#  88,
#  51,
#  18,
#  17,
#  69,
#  97,
#  89,
#  52,
#  1,
#  74,
#  75,
#  28,
#  75,
#  33,
#  83,
#  21,
#  50,
#  9,
#  88,
#  8,
#  26,
#  69,
#  81,
#  61,
#  17,
#  85,
#  71,
#  60,
#  80,
#  84,
#  32,
#  27,
#  91,
#  13,
#  30,
#  79,
#  0,
#  51,
#  100,
#  10,
#  23,
#  88,
#  77,
#  65,
#  8,
#  64,
#  1,
#  42,
#  18,
#  5,
#  74,
#  75,
#  47,
#  95,
#  57,
#  43,
#  49,
#  30,
#  45,
#  67,
#  2,
#  60,
#  63,
#  42,
#  98,
#  87,
#  91,
#  29,
#  16,
#  15,
#  11,
#  18,
#  30,
#  55,
#  47,
#  8,
#  64,
#  24,
#  44,
#  29,
#  4,
#  31,
#  6,
#  6,
#  92,
#  40,
#  76,
#  27,
#  76,
#  83,
#  53,
#  92,
#  18,
#  46,
#  81,
#  88,
#  95,
#  22,
#  57,
#  43,
#  59,
#  49,
#  74,
#  4,
#  54,
#  53,
#  31,
#  41,
#  19,
#  86,
#  11,
#  54,
#  11,
#  13,
#  11,
#  87,
#  69,
#  15,
#  77,
#  88,
#  91,
#  68,
#  81,
#  74,
#  42,
#  12,
#  47,
#  64,
#  42,
#  13,
#  51,
#  16,
#  39,
#  7,
#  82,
#  14,
#  48,
#  34,
#  99,
#  92,
#  90,
#  42,
#  42,
#  87,
#  56,
#  74,
#  18,
#  64,
#  73,
#  17,
#  62,
#  48,
#  64,
#  43,
#  30,
#  62,
#  89,
#  52,
#  59,
#  62,
#  71,
#  96,
#  62,
#  56,
#  96,
#  58,
#  70,
#  4,
#  96,
#  72,
#  35,
#  32,
#  11,
#  26,
#  44,
#  69,
#  8,
#  40,
#  28,
#  43,
#  77,
#  36,
#  59,
#  28,
#  93,
#  97,
#  100,
#  76,
#  58,
#  61,
#  4,
#  64,
#  87,
#  29,
#  52,
#  35,
#  82,
#  24,
#  96,
#  18,
#  82,
#  89,
#  57,
#  48,
#  21,
#  53,
#  81,
#  39,
#  83,
#  63,
#  52,
#  39,
#  93,
#  51,
#  38,
#  96,
#  3,
#  52,
#  68,
#  93,
#  65,
#  47,
#  34,
#  97,
#  18,
#  39,
#  20,
#  58,
#  66,
#  85,
#  47,
#  5,
#  65,
#  11,
#  75,
#  8,
#  71,
#  98,
#  85,
#  8,
#  96,
#  22,
#  31,
#  66,
#  58,
#  91,
#  43,
#  79,
#  66,
#  94,
#  49,
#  67,
#  98,
#  97,
#  21,
#  40]

# %%
max(list_with_random_numbers)
# Out:
# 100

# %%
min(list_with_random_numbers)
# Out:
# 0

# %%
import statistics
statistics.median(list_with_random_numbers)
# Out:
# 52.0

# %%
new_dict = dict((x, list_with_random_numbers.count(x)) for x in set(list_with_random_numbers) if list_with_random_numbers.count(x) > 1)
new_dict
# Out:
# {0: 7,
#  1: 11,
#  2: 12,
#  3: 8,
#  4: 15,
#  5: 9,
#  6: 10,
#  7: 7,
#  8: 10,
#  9: 3,
#  10: 10,
#  11: 15,
#  12: 10,
#  13: 3,
#  14: 5,
#  15: 8,
#  16: 7,
#  17: 11,
#  18: 16,
#  19: 6,
#  20: 6,
#  21: 7,
#  22: 7,
#  23: 8,
#  24: 10,
#  25: 9,
#  26: 13,
#  27: 7,
#  28: 15,
#  29: 11,
#  30: 8,
#  31: 13,
#  32: 12,
#  33: 13,
#  34: 7,
#  35: 15,
#  36: 6,
#  37: 6,
#  38: 7,
#  39: 7,
#  40: 9,
#  41: 6,
#  42: 16,
#  43: 17,
#  44: 8,
#  45: 9,
#  46: 4,
#  47: 12,
#  48: 13,
#  49: 12,
#  50: 8,
#  51: 13,
#  52: 12,
#  53: 13,
#  54: 6,
#  55: 8,
#  56: 8,
#  57: 14,
#  58: 12,
#  59: 9,
#  60: 8,
#  61: 7,
#  62: 9,
#  63: 10,
#  64: 11,
#  65: 11,
#  66: 12,
#  67: 8,
#  68: 7,
#  69: 9,
#  70: 8,
#  71: 13,
#  72: 5,
#  73: 13,
#  74: 12,
#  75: 12,
#  76: 11,
#  77: 14,
#  78: 15,
#  79: 10,
#  80: 8,
#  81: 8,
#  82: 14,
#  83: 13,
#  84: 5,
#  85: 8,
#  86: 5,
#  87: 7,
#  88: 20,
#  89: 10,
#  90: 7,
#  91: 12,
#  92: 8,
#  93: 9,
#  94: 15,
#  95: 12,
#  96: 12,
#  97: 10,
#  98: 11,
#  99: 10,
#  100: 12}

# %%
import numpy as np

# %%
 np.std(list_with_random_numbers, axis=None, dtype=None)
# Out:
# 29.151603660862296

# %%
statistics.stdev(list_with_random_numbers)
# Out:
# 29.166190403661954
